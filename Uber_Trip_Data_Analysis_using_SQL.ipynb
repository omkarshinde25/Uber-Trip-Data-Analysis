# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarshinde25/Uber-Trip-Analysis/blob/main/Uber_Trip_Data_Analysis_using_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_excel('/content/drive/MyDrive/Uber Trip Details.xlsx')

# %%
df
# Out:
#         Trip ID         Pickup Time       Drop Off Time  passenger_count  \
# 0             1 2024-06-01 00:42:50 2024-06-01 01:04:33                1
# 1             2 2024-06-01 00:06:29 2024-06-01 00:13:22                1
# 2             3 2024-06-01 00:08:05 2024-06-01 00:21:33                1
# 3             4 2024-06-01 00:28:20 2024-06-01 00:37:46                1
# 4             5 2024-06-01 00:38:05 2024-06-01 00:45:05                1
# ...         ...                 ...                 ...              ...
# 103723   116918 2024-06-30 23:17:26 2024-06-30 23:35:00                1
# 103724   116919 2024-06-30 23:08:12 2024-06-30 23:14:02                1
# 103725   116920 2024-06-30 23:38:39 2024-06-30 23:42:56                1
# 103726   116923 2024-06-30 23:57:00 2024-07-01 00:05:46                1
# 103727   116924 2024-06-30 23:08:13 2024-06-30 23:19:19                1
#
#         trip_distance  PULocationID  DOLocationID  fare_amount  Surge Fee  \
# ...

# %%
df.columns
# Out:
# Index(['Trip ID', 'Pickup Time', 'Drop Off Time', 'passenger_count',
#        'trip_distance', 'PULocationID', 'DOLocationID', 'fare_amount',
#        'Surge Fee', 'Vehicle', 'Payment_type'],
#       dtype='object')

# %%
import sqlite3
from IPython.display import display

# %%
conn=sqlite3.connect('test.db')
df.to_sql("TripDetail",conn,if_exists="replace", index="false")
# Out:
# 103728

# %% [markdown]
# 1. Display all records:

# %%
query="select * from tripdetail"
result=pd.read_sql(query,conn)
display(result)
# Out:
#          false  Trip ID          Pickup Time        Drop Off Time  \
# 0            0        1  2024-06-01 00:42:50  2024-06-01 01:04:33
# 1            1        2  2024-06-01 00:06:29  2024-06-01 00:13:22
# 2            2        3  2024-06-01 00:08:05  2024-06-01 00:21:33
# 3            3        4  2024-06-01 00:28:20  2024-06-01 00:37:46
# 4            4        5  2024-06-01 00:38:05  2024-06-01 00:45:05
# ...        ...      ...                  ...                  ...
# 103723  103723   116918  2024-06-30 23:17:26  2024-06-30 23:35:00
# 103724  103724   116919  2024-06-30 23:08:12  2024-06-30 23:14:02
# 103725  103725   116920  2024-06-30 23:38:39  2024-06-30 23:42:56
# 103726  103726   116923  2024-06-30 23:57:00  2024-07-01 00:05:46
# 103727  103727   116924  2024-06-30 23:08:13  2024-06-30 23:19:19
#
#         passenger_count  trip_distance  PULocationID  DOLocationID  \
# 0                     1           5.60            79           226
# ...

# %% [markdown]
# 2. Count total trips

# %%
query= "select count(*) from tripdetail"
result=pd.read_sql(query,conn)
display(result)
# Out:
#    count(*)
# 0    103728

# %% [markdown]
# 3. List unique vehicle types:

# %%
query= "select distinct vehicle from tripdetail"
result=pd.read_sql(query,conn)
display(result)
# Out:
#         Vehicle
# 0         UberX
# 1    Uber Black
# 2  Uber Comfort
# 3    Uber Green
# 4        UberXL

# %% [markdown]
# 4. Trips with fare > 100:

# %%
query= "select * from tripdetail where fare_amount>100"
result=pd.read_sql(query,conn)
display(result)
# Out:
#      false  Trip ID          Pickup Time        Drop Off Time  \
# 0     7040     7817  2024-06-03 14:07:11  2024-06-03 17:27:07
# 1    10154    11404  2024-06-04 16:53:55  2024-06-04 21:07:23
# 2    12001    13538  2024-06-05 12:04:50  2024-06-05 14:50:20
# 3    13068    14781  2024-06-05 17:04:56  2024-06-05 19:46:04
# 4    30077    32045  2024-06-11 09:56:26  2024-06-11 13:31:33
# 5    30354    32322  2024-06-11 10:04:39  2024-06-11 13:06:00
# 6    30385    32353  2024-06-11 10:17:39  2024-06-11 14:12:42
# 7    36255    38503  2024-06-12 18:06:30  2024-06-12 19:43:23
# 8    36618    38935  2024-06-12 20:31:36  2024-06-12 21:24:16
# 9    40397    43342  2024-06-14 14:07:19  2024-06-14 15:03:25
# 10   53093    58035  2024-06-18 10:03:08  2024-06-18 13:03:43
# 11   70453    78275  2024-06-23 09:59:37  2024-06-23 14:52:33
# 12   71683    79715  2024-06-23 14:56:14  2024-06-23 18:57:57
# 13   71893    79961  2024-06-23 14:17:11  2024-06-23 15:47:37
# ...

# %% [markdown]
# 5. Uber Black trips

# %%
query= "select * from tripdetail where Vehicle='Uber Black'"
result=pd.read_sql(query,conn)
display(result)
# Out:
#         false  Trip ID          Pickup Time        Drop Off Time  \
# 0           1        2  2024-06-01 00:06:29  2024-06-01 00:13:22
# 1           2        3  2024-06-01 00:08:05  2024-06-01 00:21:33
# 2           4        5  2024-06-01 00:38:05  2024-06-01 00:45:05
# 3          15       16  2024-06-01 00:46:55  2024-06-01 00:53:12
# 4          35       37  2024-06-01 01:32:31  2024-06-01 01:55:17
# ...       ...      ...                  ...                  ...
# 16705  103699   116887  2024-06-30 23:45:16  2024-06-30 23:49:53
# 16706  103711   116902  2024-06-30 23:21:39  2024-06-30 23:38:43
# 16707  103712   116903  2024-06-30 23:16:23  2024-06-30 23:21:42
# 16708  103723   116918  2024-06-30 23:17:26  2024-06-30 23:35:00
# 16709  103727   116924  2024-06-30 23:08:13  2024-06-30 23:19:19
#
#        passenger_count  trip_distance  PULocationID  DOLocationID  \
# 0                    1           1.72           142           186
# ...

# %% [markdown]
# 6. Total passengers

# %%
query= "select sum(passenger_count) as 'Total Passengers' from tripdetail"
result=pd.read_sql(query,conn)
display(result)
# Out:
#    Total Passengers
# 0            146478

# %% [markdown]
# 7. Average trip distance:

# %%
query= "select avg(trip_distance) as 'Avg Trip Distance' from tripdetail"
result=pd.read_sql(query,conn)
display(result)
# Out:
#    Avg Trip Distance
# 0           3.363931

# %% [markdown]
# 8. Total fare per vehicle:

# %%
query= "select vehicle, sum(fare_amount) as 'Total Fare' from tripdetail group by vehicle "
result=pd.read_sql(query,conn)
display(result)
# Out:
#         Vehicle  Total Fare
# 0    Uber Black   217094.00
# 1  Uber Comfort   220584.98
# 2    Uber Green   187445.20
# 3         UberX   507140.77
# 4        UberXL   216026.50

# %% [markdown]
# 9. Average fare per vehicle:

# %%
query= "select vehicle, avg(fare_amount) as 'Avg Fare_Amount' from tripdetail group by vehicle"
result=pd.read_sql(query,conn)
display(result)
# Out:
#         Vehicle  Avg Fare_Amount
# 0    Uber Black        12.991861
# 1  Uber Comfort        12.916324
# 2    Uber Green        12.929038
# 3         UberX        13.089531
# 4        UberXL        12.937268

# %% [markdown]
# 10. Payment methods where avg fare > 200:

# %%
query= "select Payment_type,avg(fare_amount) as Avg_fare from tripdetail group by payment_type having avg(fare_amount)>200"
result=pd.read_sql(query,conn)
display(result)
# Out:
# Empty DataFrame
# Columns: [Payment_type, Avg_fare]
# Index: []

# %% [markdown]
# 11. Trip count per payment type:

# %%
query= "select Payment_type, count(*) as 'Trip Count' from tripdetail group by payment_type "
result=pd.read_sql(query,conn)
display(result)
# Out:
#   Payment_type  Trip Count
# 0   Amazon Pay         584
# 1         Cash       33434
# 2   Google Pay         180
# 3     Uber Pay       69530

# %% [markdown]
# 12. Highest fare with vehicle:

# %%
query= "select vehicle, max(fare_amount) as 'Highest Fare Amount' from tripdetail group by vehicle"
result=pd.read_sql(query,conn)
display(result)
# Out:
#         Vehicle  Highest Fare Amount
# 0    Uber Black               204.00
# 1  Uber Comfort               141.00
# 2    Uber Green               212.50
# 3         UberX               563.79
# 4        UberXL               160.50

# %% [markdown]
# 13. Trips + avg fare per vehicle:

# %%
query= "select vehicle, count(*) as 'Trips', avg(fare_amount) from tripdetail group by vehicle"
result=pd.read_sql(query,conn)
display(result)
# Out:
#         Vehicle  Trips  avg(fare_amount)
# 0    Uber Black  16710         12.991861
# 1  Uber Comfort  17078         12.916324
# 2    Uber Green  14498         12.929038
# 3         UberX  38744         13.089531
# 4        UberXL  16698         12.937268

# %% [markdown]
# 14. Top 5 longest trips:

# %%
query= "select * from tripdetail order by trip_distance desc limit 5"
result=pd.read_sql(query,conn)
display(result)
# Out:
#    false  Trip ID          Pickup Time        Drop Off Time  passenger_count  \
# 0  92204   103565  2024-06-28 10:50:50  2024-06-28 19:42:41                1
# 1  13068    14781  2024-06-05 17:04:56  2024-06-05 19:46:04                1
# 2  30385    32353  2024-06-11 10:17:39  2024-06-11 14:12:42                1
# 3  79558    88894  2024-06-25 10:11:52  2024-06-25 14:19:43                1
# 4  40397    43342  2024-06-14 14:07:19  2024-06-14 15:03:25                1
#
#    trip_distance  PULocationID  DOLocationID  fare_amount  Surge Fee  \
# 0         144.10           148            61       563.79       0.00
# 1         125.50           186            39       328.50      74.51
# 2          62.40           162           162       204.00      41.90
# 3          61.37           162           162       212.50      45.61
# 4          51.20           132           265       131.00     100.00
#
#       Vehicle Payment_type
# 0       UberX     Uber Pay
# 1       UberX     Uber Pay
# ...

# %% [markdown]
# 15. Bottom 5 shortest trips:

# %%
query= "select * from tripdetail order by trip_distance limit 5"
result=pd.read_sql(query,conn)
display(result)
# Out:
#    false  Trip ID          Pickup Time        Drop Off Time  passenger_count  \
# 0    166      168  2024-06-01 06:22:28  2024-06-01 06:26:00                2
# 1    331      333  2024-06-01 07:10:53  2024-06-01 07:14:26                1
# 2    844      846  2024-06-01 10:21:40  2024-06-01 10:28:35                1
# 3   1009     1011  2024-06-01 11:26:57  2024-06-01 11:31:24                1
# 4   1363     1365  2024-06-01 13:28:01  2024-06-01 13:33:51                2
#
#    trip_distance  PULocationID  DOLocationID  fare_amount  Surge Fee  \
# 0           1.01           170           161          5.0       1.66
# 1           1.01           226             7          5.0       0.00
# 2           1.01           237           236          7.0       0.00
# 3           1.01            43           142          5.5       2.20
# 4           1.01           141           237          6.0       1.00
#
#         Vehicle Payment_type
# 0         UberX     Uber Pay
# ...

# %% [markdown]
# 16. Trips with fare > average fare:

# %%
query= "select * from tripdetail where fare_amount>(select avg(fare_amount) from tripdetail)"
result=pd.read_sql(query,conn)
display(result)
# Out:
#         false  Trip ID          Pickup Time        Drop Off Time  \
# 0           0        1  2024-06-01 00:42:50  2024-06-01 01:04:33
# 1           2        3  2024-06-01 00:08:05  2024-06-01 00:21:33
# 2           5        6  2024-06-01 00:06:00  2024-06-01 00:22:17
# 3          10       11  2024-06-01 00:18:51  2024-06-01 00:37:05
# 4          11       12  2024-06-01 00:17:18  2024-06-01 00:40:23
# ...       ...      ...                  ...                  ...
# 33972  103716   116909  2024-06-30 23:09:38  2024-06-30 23:26:46
# 33973  103718   116912  2024-06-30 23:30:44  2024-06-30 23:49:49
# 33974  103721   116915  2024-06-30 23:46:04  2024-07-01 00:06:16
# 33975  103723   116918  2024-06-30 23:17:26  2024-06-30 23:35:00
# 33976  103727   116924  2024-06-30 23:08:13  2024-06-30 23:19:19
#
#        passenger_count  trip_distance  PULocationID  DOLocationID  \
# 0                    1           5.60            79           226
# ...

# %% [markdown]
# 17. Trips longer than avg distance:

# %%
query= "select * from tripdetail where trip_distance > (select avg(trip_distance) from tripdetail) "
result=pd.read_sql(query,conn)
display(result)
# Out:
#         false  Trip ID          Pickup Time        Drop Off Time  \
# 0           0        1  2024-06-01 00:42:50  2024-06-01 01:04:33
# 1           2        3  2024-06-01 00:08:05  2024-06-01 00:21:33
# 2           7        8  2024-06-01 00:32:01  2024-06-01 00:42:50
# 3          10       11  2024-06-01 00:18:51  2024-06-01 00:37:05
# 4          11       12  2024-06-01 00:17:18  2024-06-01 00:40:23
# ...       ...      ...                  ...                  ...
# 31032  103716   116909  2024-06-30 23:09:38  2024-06-30 23:26:46
# 31033  103718   116912  2024-06-30 23:30:44  2024-06-30 23:49:49
# 31034  103721   116915  2024-06-30 23:46:04  2024-07-01 00:06:16
# 31035  103723   116918  2024-06-30 23:17:26  2024-06-30 23:35:00
# 31036  103727   116924  2024-06-30 23:08:13  2024-06-30 23:19:19
#
#        passenger_count  trip_distance  PULocationID  DOLocationID  \
# 0                    1           5.60            79           226
# ...

# %% [markdown]
# 18. Vehicles with total fare > overall avg fare:

# %%
query= "select vehicle, fare_amount from tripdetail group by vehicle having sum(fare_amount) > (select avg(fare_amount) from tripdetail)"
result=pd.read_sql(query,conn)
display(result)
# Out:
#         Vehicle  fare_amount
# 0    Uber Black          8.0
# 1  Uber Comfort         12.5
# 2    Uber Green          5.5
# 3         UberX         19.5
# 4        UberXL         22.0

# %% [markdown]
# 20. Trips with fare > min UberX fare:

# %%
query= "select * from tripdetail where fare_amount > (select min(fare_amount) from tripdetail where vehicle='uberx')"
result=pd.read_sql(query,conn)
display(result)
# Out:
# Empty DataFrame
# Columns: [false, Trip ID, Pickup Time, Drop Off Time, passenger_count, trip_distance, PULocationID, DOLocationID, fare_amount, Surge Fee, Vehicle, Payment_type]
# Index: []

# %% [markdown]
# Use ALTER TABLE … RENAME COLUMN to fix space-related errors by renaming the column to a name without spaces.

# %%
conn.execute('alter table tripdetail rename column "Pickup Time" to "pickup_time";')
conn.commit()

# %%
conn.execute('alter table tripdetail rename column "Trip ID" to trip_id;')
conn.commit()

# %%
conn.execute('alter table tripdetail rename column "Drop Off Time" to drop_off_time;')
conn.commit()

# %%
conn.execute('alter table tripdetail rename column "Surge Fee" to surge_fee;')
conn.commit()

# %%
pd.read_sql("pragma table_info(tripdetail);", conn)
# Out:
#     cid             name       type  notnull dflt_value  pk
# 0     0            false    INTEGER        0       None   0
# 1     1          trip_id    INTEGER        0       None   0
# 2     2      pickup_time  TIMESTAMP        0       None   0
# 3     3    drop_off_time  TIMESTAMP        0       None   0
# 4     4  passenger_count    INTEGER        0       None   0
# 5     5    trip_distance       REAL        0       None   0
# 6     6     PULocationID    INTEGER        0       None   0
# 7     7     DOLocationID    INTEGER        0       None   0
# 8     8      fare_amount       REAL        0       None   0
# 9     9        surge_fee       REAL        0       None   0
# 10   10          Vehicle       TEXT        0       None   0
# 11   11     Payment_type       TEXT        0       None   0

# %% [markdown]
# 21. Trips in June 2024

# %%
query = "select * from tripdetail where strftime('%Y-%m', Pickup_Time) = '2024-06'"
result = pd.read_sql(query, conn)
display(result)
# Out:
#          false  trip_id          pickup_time        drop_off_time  \
# 0            0        1  2024-06-01 00:42:50  2024-06-01 01:04:33
# 1            1        2  2024-06-01 00:06:29  2024-06-01 00:13:22
# 2            2        3  2024-06-01 00:08:05  2024-06-01 00:21:33
# 3            3        4  2024-06-01 00:28:20  2024-06-01 00:37:46
# 4            4        5  2024-06-01 00:38:05  2024-06-01 00:45:05
# ...        ...      ...                  ...                  ...
# 103723  103723   116918  2024-06-30 23:17:26  2024-06-30 23:35:00
# 103724  103724   116919  2024-06-30 23:08:12  2024-06-30 23:14:02
# 103725  103725   116920  2024-06-30 23:38:39  2024-06-30 23:42:56
# 103726  103726   116923  2024-06-30 23:57:00  2024-07-01 00:05:46
# 103727  103727   116924  2024-06-30 23:08:13  2024-06-30 23:19:19
#
#         passenger_count  trip_distance  PULocationID  DOLocationID  \
# 0                     1           5.60            79           226
# ...

# %% [markdown]
# 22. Trips per day:

# %%
query = "select strftime('%Y-%m-%d', Pickup_Time) as Day, count(*) from tripdetail group by day"
result = pd.read_sql(query, conn)
display(result)
# Out:
#            Day  count(*)
# 0   2024-06-01      2971
# 1   2024-06-02      2648
# 2   2024-06-03      2546
# 3   2024-06-04      2830
# 4   2024-06-05      2894
# 5   2024-06-06      2442
# 6   2024-06-07      2099
# 7   2024-06-08      3484
# 8   2024-06-09      3773
# 9   2024-06-10      3722
# 10  2024-06-11      3710
# 11  2024-06-12      3815
# 12  2024-06-13      2666
# 13  2024-06-14      1934
# 14  2024-06-15      3383
# 15  2024-06-16      3594
# 16  2024-06-17      3737
# 17  2024-06-18      3814
# 18  2024-06-19      4062
# 19  2024-06-20      2774
# 20  2024-06-21      2391
# 21  2024-06-22      4227
# 22  2024-06-23      4457
# 23  2024-06-24      4648
# 24  2024-06-25      4744
# 25  2024-06-26      4947
# 26  2024-06-27      3289
# 27  2024-06-28      2836
# 28  2024-06-29      4598
# 29  2024-06-30      4693

# %% [markdown]
# 23. Extract hour from pickup time:

# %%
query = "select strftime('%H', Pickup_Time) as Hour, count(*) from tripdetail group by Hour"
result = pd.read_sql(query, conn)
display(result)
# Out:
#    Hour  count(*)
# 0    00      1346
# 1    01       829
# 2    02       477
# 3    03       337
# 4    04       331
# 5    05       982
# 6    06      2834
# 7    07      4135
# 8    08      4967
# 9    09      5641
# 10   10      5970
# 11   11      6602
# 12   12      7163
# 13   13      7226
# 14   14      7694
# 15   15      7908
# 16   16      7576
# 17   17      7801
# 18   18      7070
# 19   19      5479
# 20   20      3694
# 21   21      3037
# 22   22      2584
# 23   23      2045

# %% [markdown]
# 24. Average trip duration (minutes):

# %%
query = "select avg((julianday (drop_off_time) - julianday(Pickup_Time))*1440) from tripdetail"
result = pd.read_sql(query, conn)
display(result)
# Out:
#    avg((julianday (drop_off_time) - julianday(Pickup_Time))*1440)
# 0                                          15.863074

# %% [markdown]
# 25. Earliest & latest trip times:

# %%
query = "select min(pickup_time),max(pickup_time) from tripdetail"
result = pd.read_sql(query, conn)
display(result)
# Out:
#       min(pickup_time)     max(pickup_time)
# 0  2024-06-01 00:00:31  2024-06-30 23:58:51

# %% [markdown]
# 26. Weekend trip count:

# %%
query = "select count(*) from tripdetail where strftime('%w', Pickup_Time) in ('0','6') "
result = pd.read_sql(query, conn)
display(result)
# Out:
#    count(*)
# 0     37828

# %% [markdown]
# 27. Monthly average fare:

# %%
query = "select avg(fare_amount),strftime('%m', Pickup_Time) as Month from tripdetail group by month "
result = pd.read_sql(query, conn)
display(result)
# Out:
#    avg(fare_amount) Month
# 0         12.998337    06

# %% [markdown]
# 28. Rank trips by fare:

# %%
query = "select trip_ID, fare_amount, rank() over (order by fare_amount desc) FROM TripDetail"
result = pd.read_sql(query, conn)
display(result)
# Out:
#         trip_id  fare_amount  rank() over (order by fare_amount desc)
# 0        103565       563.79                                        1
# 1         14781       328.50                                        2
# 2         88894       212.50                                        3
# 3         32353       204.00                                        4
# 4         78275       199.00                                        5
# ...         ...          ...                                      ...
# 103723   102217         2.50                                   103680
# 103724   102743         2.50                                   103680
# 103725   103895         2.50                                   103680
# 103726   105612         2.50                                   103680
# 103727   106215         2.50                                   103680
#
# [103728 rows x 3 columns]

# %% [markdown]
# 29. Top 10 longest trips:

# %%
query = "select * from tripdetail order by trip_distance desc limit 10"
result = pd.read_sql(query, conn)
display(result)
# Out:
#    false  trip_id          pickup_time        drop_off_time  passenger_count  \
# 0  92204   103565  2024-06-28 10:50:50  2024-06-28 19:42:41                1
# 1  13068    14781  2024-06-05 17:04:56  2024-06-05 19:46:04                1
# 2  30385    32353  2024-06-11 10:17:39  2024-06-11 14:12:42                1
# 3  79558    88894  2024-06-25 10:11:52  2024-06-25 14:19:43                1
# 4  40397    43342  2024-06-14 14:07:19  2024-06-14 15:03:25                1
# 5  98799   111181  2024-06-29 21:46:38  2024-06-29 22:38:44                1
# 6  53093    58035  2024-06-18 10:03:08  2024-06-18 13:03:43                1
# 7  83212    93151  2024-06-25 22:24:55  2024-06-25 23:35:05                1
# 8  70453    78275  2024-06-23 09:59:37  2024-06-23 14:52:33                1
# 9  72223    80339  2024-06-23 15:55:35  2024-06-23 17:12:27                1
#
#    trip_distance  PULocationID  DOLocationID  fare_amount  surge_fee  \
# ...

# %% [markdown]
# 30. Fare percentage share per vehicle:

# %%
query = "select vehicle,sum(fare_amount), round(sum(fare_amount)*100.0/(select sum(fare_amount) from tripdetail),2) as Percentage from tripdetail group by vehicle"
result = pd.read_sql(query, conn)
display(result)
# Out:
#         Vehicle  sum(fare_amount)  Percentage
# 0    Uber Black         217094.00       16.10
# 1  Uber Comfort         220584.98       16.36
# 2    Uber Green         187445.20       13.90
# 3         UberX         507140.77       37.61
# 4        UberXL         216026.50       16.02

# %% [markdown]
# 31. Compare weekday vs weekend avg fare:

# %%
query = "select case when strftime('%w', pickup_time) in ('0','6') then 'weekend' else 'weekday' end as daytype, avg(fare_amount) from tripdetail group by daytype"
result = pd.read_sql(query, conn)
display(result)
# Out:
#    daytype  avg(fare_amount)
# 0  weekday         13.093980
# 1  weekend         12.831716

# %% [markdown]
# 32. Pickup location with highest avg distance:

# %%
query = "select pulocationid, avg(trip_distance) from tripdetail group by pulocationid order by avg(trip_distance) desc limit 1;"
result = pd.read_sql(query, conn)
display(result)
# Out:
#    PULocationID  avg(trip_distance)
# 0           204               44.61

# %% [markdown]
# 33. Revenue per vehicle per month:

# %%
query = "select vehicle, strftime('%m',pickup_time) as month, sum(fare_amount) from tripdetail group by vehicle,month"
result = pd.read_sql(query, conn)
display(result)
# Out:
#         Vehicle month  sum(fare_amount)
# 0    Uber Black    06         217094.00
# 1  Uber Comfort    06         220584.98
# 2    Uber Green    06         187445.20
# 3         UberX    06         507140.77
# 4        UberXL    06         216026.50

# %% [markdown]
# 34. Vehicles with long trips across multiple months:

# %%
query = "select vehicle, trip_distance from tripdetail where trip_distance > (select avg(trip_distance) from tripdetail) group by vehicle having count(distinct strftime('%y-%m', pickup_time)) > 1;"
result = pd.read_sql(query, conn)
display(result)
# Out:
# Empty DataFrame
# Columns: [Vehicle, trip_distance]
# Index: []

# %% [markdown]
# 36. Highest Fare trip:

# %%
query = "select vehicle,max(fare_amount) from tripdetail order by fare_amount desc limit 1"
result = pd.read_sql(query, conn)
display(result)
# Out:
#   Vehicle  max(fare_amount)
# 0   UberX            563.79

# %% [markdown]
# 37. Count trips with passenger_count > 3:

# %%
query = "select count(*) from tripdetail where passenger_count>3"
result = pd.read_sql(query, conn)
display(result)
# Out:
#    count(*)
# 0      5732

# %% [markdown]
# 38. Average distance per passenger count:

# %%
query = "select avg(trip_distance), passenger_count from tripdetail group by passenger_count"
result = pd.read_sql(query, conn)
display(result)
# Out:
#    avg(trip_distance)  passenger_count
# 0            3.348294                1
# 1            3.470296                2
# 2            3.322931                3
# 3            3.556590                4
# 4            3.228137                5
# 5            3.461785                6

# %% [markdown]
# 39. Total revenue of entire dataset:

# %%
query = "select sum(fare_amount) as 'Total Revenue' from tripdetail"
result = pd.read_sql(query, conn)
display(result)
# Out:
#    Total Revenue
# 0     1348291.45

# %% [markdown]
# 40. Trips where fare is between 50 and 150:

# %%
query = "select * from tripdetail where fare_amount between 50 and 150"
result = pd.read_sql(query, conn)
display(result)
# Out:
#       false  trip_id          pickup_time        drop_off_time  \
# 0        51       53  2024-06-01 01:49:56  2024-06-02 01:24:56
# 1       149      151  2024-06-01 06:06:57  2024-06-01 06:42:43
# 2       230      232  2024-06-01 06:57:02  2024-06-01 07:33:02
# 3       369      371  2024-06-01 07:19:10  2024-06-01 08:02:34
# 4       526      528  2024-06-01 08:44:34  2024-06-01 10:24:46
# ..      ...      ...                  ...                  ...
# 886  102517   115509  2024-06-30 17:53:28  2024-06-30 18:44:23
# 887  102587   115590  2024-06-30 17:39:46  2024-06-30 18:28:23
# 888  102597   115602  2024-06-30 17:09:11  2024-06-30 18:09:53
# 889  102606   115613  2024-06-30 17:05:16  2024-06-30 18:25:04
# 890  103542   116710  2024-06-30 22:28:44  2024-06-30 23:34:21
#
#      passenger_count  trip_distance  PULocationID  DOLocationID  fare_amount  \
# 0                  1          19.31            35           115         53.5
# ...
